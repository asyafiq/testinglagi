# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import sklearn as sk
import tweepy
#import jsonpick

# %%
consumerKey = 'PEYBdJI2SFqD93W3j3ZwhGS1z'
consumerSecret = 'SDHZwc9X7BFUR0WHoSJSdZBIQBM5jxIIreEdvoABvfH6cAq3d5'

#Use tweepy.OAuthHandler to create an authentication using the given key and secret
auth = tweepy.OAuthHandler(consumer_key=consumerKey,consumer_secret=consumerSecret)
access_token = '2157899096-iKCDMbHXm6iKeU18N2exQ9U8tNWqCB1P6JrgIAL'
access_token_secret = 'rWPkxdUoVrYdpIRy2GlSTCeVrJJe21IUcswN2rPL49qj3'
#auth.set_access_token(access_token, access_token_secret)

#Connect to the Twitter API using the authentication
api = tweepy.API(auth)

# %% [markdown]
# # SEARCHED BY KEYWORD

# %%
results = []
import time
start_time = time.time()
#Get the first 5000 items based on the search query
for tweet in tweepy.Cursor(api.search, q='tiket.com',lang='id', count=5000).items():
    results.append(tweet)

# Verify the number of items returned
def toDataFrame(tweets):

    DataSet = pd.DataFrame()

    DataSet['tweetID'] = [tweet.id for tweet in tweets]
    DataSet['tweetText'] = [tweet.text for tweet in tweets]
    DataSet['tweetRetweetCt'] = [tweet.retweet_count for tweet 
    in tweets]
    DataSet['tweetFavoriteCt'] = [tweet.favorite_count for tweet 
    in tweets]
    DataSet['tweetSource'] = [tweet.source for tweet in tweets]
    DataSet['tweetCreated'] = [tweet.created_at for tweet in tweets]


    DataSet['userID'] = [tweet.user.id for tweet in tweets]
    DataSet['userScreen'] = [tweet.user.screen_name for tweet 
    in tweets]
    DataSet['userName'] = [tweet.user.name for tweet in tweets]
    DataSet['userCreateDt'] = [tweet.user.created_at for tweet 
    in tweets]
    DataSet['userDesc'] = [tweet.user.description for tweet in tweets]
    DataSet['userFollowerCt'] = [tweet.user.followers_count for tweet 
    in tweets]
    DataSet['userFriendsCt'] = [tweet.user.friends_count for tweet 
    in tweets]
    DataSet['userLocation'] = [tweet.user.location for tweet in tweets]
    DataSet['coordinates'] = [tweet.coordinates for tweet in tweets]
    DataSet['geolocation'] = [tweet.geo for tweet in tweets]
    DataSet['userTimezone'] = [tweet.user.time_zone for tweet 
    in tweets]
    

    return DataSet

# create a DataFrame
DataSet = toDataFrame(results)
DataSet1=DataSet[['userID','userScreen','userName','userLocation','coordinates','geolocation','userTimezone','tweetText','tweetCreated','tweetSource','tweetRetweetCt']]


print("--- %s detik --- atau %s menit" % ((time.time() - start_time),(time.time() - start_time)/60))
print len(DataSet1)
# Out:
# --- 176.644000053 detik --- atau 2.94406666756 menit
# 771

# %%
DataSet1=DataSet[['userID','userScreen','userName','userLocation','coordinates','geolocation','userTimezone','tweetText','tweetCreated','tweetSource','tweetRetweetCt']]
DataSet1
# Out:
#                  userID      userScreen            userName  \
# 0            3042404540    GaleriApaaja        GaleriApaAJa
# 1            2907567296          867Evo                 evo
# 2    754019764633276416    tutorial_kom           News_Tech
# 3            2361166844     sahrudin06_     MuhamadSahrudin
# 4            2907567296          867Evo                 evo
# 5             113328047        tsuroiya      ienas Tsuroiya
# 6            3042404540    GaleriApaaja        GaleriApaAJa
# 7            2907567296          867Evo                 evo
# 8            2888187073       TikaAyu86             Kartika
# 9            2888187073       TikaAyu86             Kartika
# 10           2888187073       TikaAyu86             Kartika
# 11           2888187073       TikaAyu86             Kartika
# 12           2888187073       TikaAyu86             Kartika
# 13             72567913      damakusuma         Dama Kusuma
# 14           3042404540    GaleriApaaja        GaleriApaAJa
# ...

# %%
DataSet1.to_excel('tiketcomA_061116_@tiketcom.xls')
